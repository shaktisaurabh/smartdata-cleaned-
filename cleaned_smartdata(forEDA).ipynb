# %%
import re 
an='123-456-7890'
pattern=re.compile(r"(\d+)(?:-)(\d+)(?:-)(\d+)")
a1=re.search(pattern,an)
print(a1.group())
# Out:
# 123-456-7890

# %%
#\b represents word characters, they donot specify character only specify position, word characters include numbers,words and
#underscores 
import re 
an='word-tryu-'
pattern=re.compile(r"\b(\w+)\b")
a1=re.search(pattern,an)
print(a1.group())
# Out:
# word

# %%
import re 
an='word-tyru-'
pattern=re.compile(r"\b(\w+)\b")
a1=re.findall(pattern,an)
print(a1)
# Out:
# ['word', 'tyru']

# %%
import re 
an='6 GB RAM'
pattern=re.compile(r"\b(\d+)\b")
a1=re.findall(pattern,an)
print(a1[0])
# Out:
# 6

# %%
import pandas as pd

# Sample DataFrame
data = {'a': [0, 1, 2], 'b': [10, 11, 12]}
df1 = pd.DataFrame(data, index=[439, 562, 789])

print("Before:")
print(df1)

# Update rows 439 and 562
df1.loc[[439, 562], ['a', 'b']] = [[4, 64], [5, 64]]

print("\nAfter:")
print(df1)
# Out:
# Before:
#      a   b
# 439  0  10
# 562  1  11
# 789  2  12
#
# After:
#      a   b
# 439  4  64
# 562  5  64
# 789  2  12

# %%
df1
# Out:
#      a   b
# 439  4  64
# 562  5  64
# 789  2  12

# %%
df1.loc[[439,562],['a','b']]
# Out:
#      a   b
# 439  4  64
# 562  5  64

# %%
df1.loc[[439,562],['a','b']].values
# Out:
# array([[ 4, 64],
#        [ 5, 64]], dtype=int64)

# %% [markdown]
# **As you can see above the values for each row has been extracted in a 2D list and so when u want to attach value to each row then you got to use a 2D list.**

# %%
import re 
a1="10w ms dhoni"
pattern=re.compile(r"(\d+)")
a1=re.findall(pattern,a1)
print(a1)
# Out:
# ['10']

# %%
import re 
a1="10w ms dhoni"
pattern=re.compile(r"(\d+)")
a1=re.search(pattern,a1)
print(a1.group())
# Out:
# 10

# %%
import re 
a1="10w ms dhoni"
pattern=re.compile(r"^\d+")
a1=re.search(pattern,a1)
print(a1.group())
# Out:
# 10

# %%
import pandas as pd 
ak=pd.read_csv(r"D:/asmart45.csv")
ak
# Out:
#      index                                phone_name   cost  spec_score  \
# 0        2                              Vivo Y300 5G  21999          83
# 1        3                        Xiaomi Redmi A4 5G   8499          70
# 2        4                        Realme GT 7 Pro 5G  59999          90
# 3        5               Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4        6                 OnePlus Nord CE 3 Lite 5G  14705          85
# ..     ...                                       ...    ...         ...
# 876   1001                           Lava Yuva 3 Pro   8998          75
# 877   1011        Realme Narzo N53 (8GB RAM + 128GB)  11000          75
# 878   1016                                   Lava O1   7999          63
# 879   1020                          Lava Blaze 2 Pro   9999          75
# 880   1021  Tecno Spark 10 Pro Moon Explorer Edition  10999          81
#
#                                      Sim_specification  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_colwidth', None)

# %%
import re
a1='Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster'
pattern=re.compile(r"\b5G\b")
match=re.search(pattern,a1)
if match:
    print('True')
else:
    print('false')
# Out:
# True

# %%
def monda(val):
    pattern=re.compile(r"\b5G\b")
    match=re.search(pattern,val)
    if match:
        return True
    else:
        return False

# %%
def NFC1(val):
    pattern1=re.compile(r"\bNFC\b")
    match=re.search(pattern1,val)
    if match:
        return True
    else:
        return False

# %%
def ir1(val):
    pattern2=re.compile(r"\bIR Blaster\b")
    match=re.search(pattern2,val)
    if match:
        return True
    else:
        return False

# %%
has_irl=ak['Sim_specification'].apply(ir1)

# %%
has_nfc=ak['Sim_specification'].apply(NFC1)

# %%
has_5g=ak['Sim_specification'].apply(monda)

# %%
ak.insert(5,'has_5g',has_5g)

# %%
ak.insert(6,'has_nfc',has_nfc)

# %%
ak.insert(7,'has_irblaster',has_irl)

# %%
ak.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed',
#        'memory_specification', 'battery_specification',
#        'display_specification', 'camera_specification',
#        'memorycard_FM_bluetooth_info', 'android_version'],
#       dtype='object')

# %%
#Quad Core, Octa Core Processor, Quad Core, 1 GHz Processor,Single Core,Octa Core,1.3 MHz Processor,

# %%
temp1=ak[ak['processor_name'].isin(['Quad Core', 'Octa Core Processor', 'Quad Core','Single Core','Octa Core'])].copy()

# %%
temp2=ak[ak['processor_name'].isin(['1 GHz Processor','1.3 MHz Processor'])].copy()

# %%
temp11=temp1[['processor_name','num_cores','processor_speed']].shift(1,axis=1)
temp11
# Out:
#     processor_name            num_cores     processor_speed
# 268            NaN  Octa Core Processor                 NaN
# 621            NaN            Quad Core   1.3 GHz Processor
# 782            NaN            Octa Core     2 GHz Processor
# 867            NaN            Octa Core   1.5 GHz Processor
# 874            NaN          Single Core     1 GHz Processor

# %%
ak.loc[temp11.index,['processor_name','num_cores','processor_speed']]=temp11.values

# %%
temp22=temp2[['processor_name','num_cores','processor_speed']].shift(2,axis=1)

# %%
ak.loc[temp22.index,['processor_name','num_cores','processor_speed']]=temp22.values

# %%
ak.to_csv(r"D:/smartbro46.csv",index=False)

# %%
ak['processor_name'].value_counts()
# Out:
# Dimensity 6300                            45
# Dimensity 6100 Plus                       35
# Helio G85                                 23
# Dimensity 7050                            22
# Snapdragon 695                            22
# Snapdragon 7 Gen3                         17
# Unisoc T606                               16
# Unisoc T612                               16
# Dimensity 6080                            16
# Dimensity 6020                            15
# Snapdragon 6 Gen1                         15
# Snapdragon 8s Gen3                        13
# Snapdragon 680                            13
# Snapdragon 8 Gen3                         13
# Snapdragon 7s Gen2                        12
# Snapdragon 8 Gen2                         12
# Snapdragon 4 Gen2                         11
# Dimensity 7300                            11
# Helio G36                                 11
# Helio P35                                 10
# Dimensity 700 5G                          10
# ...

# %%
processor_name=ak['Processor_specification'].str.split(',').str.get(0).str.strip()

# %%
ak.insert(9,'processor_name',processor_name)

# %%
processor_speed=ak['Processor_specification'].str.split(',').str.get(2).str.strip()

# %%
ak.insert(11,'processor_speed',processor_speed)

# %%
ak['Processor_specification'].str.split(',').str.get(1).value_counts()
# Out:
#  Octa Core              794
#  Hexa Core               38
#  Octa Core Processor     13
#  Deca Core                7
#  Quad Core                5
#  Hexa Core Processor      4
#  Nine Core                2
#  Nine-Cores               2
#  Nine Cores               2
#  Dual Core                1
#  1.3 GHz Processor        1
#  2 GHz Processor          1
#  1.5 GHz Processor        1
#  1 GHz Processor          1
# Name: Processor_specification, dtype: int64

# %%
ps1=ak['Processor_specification'].str.split(',').str.get(1).str.replace('Octa Core Processor','Octa Core')
ps1.value_counts()
# Out:
#  Octa Core              807
#  Hexa Core               38
#  Deca Core                7
#  Quad Core                5
#  Hexa Core Processor      4
#  Nine Core                2
#  Nine-Cores               2
#  Nine Cores               2
#  Dual Core                1
#  1.3 GHz Processor        1
#  2 GHz Processor          1
#  1.5 GHz Processor        1
#  1 GHz Processor          1
# Name: Processor_specification, dtype: int64

# %%
ps2=ps1.str.replace('Hexa Core Processor','Hexa Core').str.replace('Nine Cores','Nine Core')
ps2.value_counts()
# Out:
#  Octa Core            807
#  Hexa Core             42
#  Deca Core              7
#  Quad Core              5
#  Nine Core              4
#  Nine-Cores             2
#  Dual Core              1
#  1.3 GHz Processor      1
#  2 GHz Processor        1
#  1.5 GHz Processor      1
#  1 GHz Processor        1
# Name: Processor_specification, dtype: int64

# %%
ps3=ps2.str.replace('Nine-Cores','Nine Core')

# %%
ak.insert(10,'num_cores',ps3)

# %%
ak.drop(columns='processor_name',inplace=True)

# %%
#Octa Core Processor,Quad Core, Single Core,1.3 MHZ Processor,1 GHz Processor,

# %%
ak[ak['Processor_specification']=='Octa Core Processor']
# Out:
#      index phone_name  cost  spec_score               Sim_specification  \
# 268    271    Lava O3  6199          58  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#      has_5g  has_nfc  has_irblaster Processor_specification  \
# 268   False    False          False     Octa Core Processor
#
#         memory_specification                    battery_specification  \
# 268  4 GB RAM, 64 GB inbuilt  5000 mAh Battery with 10W Fast Charging
#
#                                         display_specification  \
# 268  6.75 inches, 1600 x 720 px Display with Water Drop Notch
#
#                     camera_specification     memorycard_FM_bluetooth_info  \
# 268  13 MP Dual Rear & 5 MP Front Camera  Memory Card (Hybrid), upto 1 TB
#
#     android_version
# 268     Android v14

# %%
ak[ak['Processor_specification'].str.contains('Quad Core')]
# Out:
#      index                                phone_name  cost  spec_score  \
# 621    659                            iKall K555 New  2874          41
# 735    794      Tecno Spark Go 2023 (3GB RAM + 64GB)  7199          64
# 792    853                   Samsung Galaxy A03 Core  7499          54
# 842    904  Samsung Galaxy M01 Core (2GB RAM + 32GB)  6490          55
# 862    925                    Xiaomi Redmi 4A (32GB)  7490          54
# 873    998                                  iKall S3  9498          68
#
#                   Sim_specification  has_5g  has_nfc  has_irblaster  \
# 621  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False          False
# 735  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False          False
# 792  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False          False
# 842  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False          False
# 862  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False          False
# ...

# %%
ak[ak['Processor_specification'].str.contains('Single Core')]
# Out:
#      index           phone_name  cost  spec_score Sim_specification  has_5g  \
# 874    999  BlackZone Taurus 4G  1959          22      Dual Sim, 4G   False
#
#      has_nfc  has_irblaster       Processor_specification  \
# 874    False          False  Single Core, 1 GHz Processor
#
#          memory_specification                battery_specification  \
# 874  48 MB RAM, 48 MB inbuilt  3000 mAh Battery with Fast Charging
#
#                 display_specification camera_specification  \
# 874  2.4 inches, 480 x 640 px Display     2 MP Rear Camera
#
#                           memorycard_FM_bluetooth_info android_version
# 874  Bluetooth  and  Memory Card Supported, upto 48 GB             NaN

# %%
ak[ak['Processor_specification'].str.contains('1.3 MHz Processor')]
# Out:
#      index phone_name  cost  spec_score Sim_specification  has_5g  has_nfc  \
# 869    978   iKall A2  1880          16          Dual Sim   False    False
# 870    979   iKall A4  1860          15          Dual Sim   False    False
#
#      has_irblaster Processor_specification      memory_specification  \
# 869          False       1.3 MHz Processor  32 MB RAM, 32 MB inbuilt
# 870          False       1.3 MHz Processor  32 MB RAM, 32 MB inbuilt
#
#     battery_specification              display_specification  \
# 869      2000 mAh Battery   2.8 inches, 280 x 320 px Display
# 870      2000 mAh Battery  3.36 inches, 280 x 320 px Display
#
#     camera_specification       memorycard_FM_bluetooth_info android_version
# 869   0.3 MP Rear Camera  Memory Card Supported, upto 64 GB         Symbian
# 870   0.3 MP Rear Camera  Memory Card Supported, upto 64 GB    Symbian v0.1

# %%
ak[ak['Processor_specification']=='1 GHz Processor']
# Out:
#      index       phone_name  cost  spec_score               Sim_specification  \
# 502    524  Itel MagicX Pro  2290          22  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#      has_5g  has_nfc  has_irblaster Processor_specification  \
# 502   False    False          False         1 GHz Processor
#
#           memory_specification battery_specification  \
# 502  64 MB RAM, 128 MB inbuilt      2500 mAh Battery
#
#                 display_specification camera_specification  \
# 502  2.4 inches, 320 x 240 px Display   0.3 MP Rear Camera
#
#                           memorycard_FM_bluetooth_info android_version
# 502  Bluetooth  and  Memory Card Supported, upto 64 GB             NaN

# %%
ak[ak['index']==524]['Processor_specification'].values[0]
# Out:
# '1 GHz Processor'

# %%
ak['Sim_specification']
# Out:
# 0                             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 3                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 4                             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 5                             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 6                  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 7                  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 8                             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 9            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 10           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 11                            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 12                       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 13                 Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# ...

# %%
import pandas as pd 
ababu=pd.read_csv(r"D:/smartbro46.csv")
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                    Sim_specification  has_5g  has_nfc  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_colwidth', None)

# %%
ababu['processor_name'].value_counts()
# Out:
# Dimensity 6300                            45
# Dimensity 6100 Plus                       35
# Helio G85                                 23
# Dimensity 7050                            22
# Snapdragon 695                            22
# Snapdragon 7 Gen3                         17
# Dimensity 6080                            16
# Unisoc T612                               16
# Unisoc T606                               16
# Snapdragon 6 Gen1                         15
# Dimensity 6020                            15
# Snapdragon 8s Gen3                        13
# Snapdragon 680                            13
# Snapdragon 8 Gen3                         13
# Snapdragon 8 Gen2                         12
# Snapdragon 7s Gen2                        12
# Helio G36                                 11
# Dimensity 7300                            11
# Snapdragon 4 Gen2                         11
# Helio P35                                 10
# Dimensity 700 5G                          10
# ...

# %%
ababu['num_cores'].value_counts()
# Out:
#  Octa Core             807
#  Hexa Core              42
#  Deca Core               7
#  Nine Core               6
#  Quad Core               5
# Octa Core                2
# Octa Core Processor      1
#  Dual Core               1
# Quad Core                1
# Single Core              1
# Name: num_cores, dtype: int64

# %%
ababu['num_cores']=ababu['num_cores'].str.strip()

# %%
ababu['num_cores'].value_counts()
# Out:
# Octa Core              809
# Hexa Core               42
# Deca Core                7
# Nine Core                6
# Quad Core                6
# Octa Core Processor      1
# Dual Core                1
# Single Core              1
# Name: num_cores, dtype: int64

# %%
ababu['processor_speed'].value_counts()
# Out:
# 2.4 GHz Processor     158
# 2.2 GHz Processor     157
# 2 GHz Processor        75
# 3 GHz Processor        47
# 3.2 GHz Processor      44
# 2.6 GHz Processor      38
# 2.5 GHz Processor      37
# 2.3 GHz Processor      36
# 2.8 GHz Processor      28
# 1.8 GHz Processor      24
# 3.1 GHz Processor      22
# 1.6 GHz Processor      19
# 2.63 GHz Processor     17
# 2.84 GHz Processor     16
# 2.05 GHz Processor     13
# 3.3 GHz Processor      13
# 2.9 GHz Processor      10
# 3.22 GHz Processor      9
# 2.85 GHz Processor      8
# 3.36 GHz Processor      8
# 4.05 GHz Processor      7
# 3.46 GHz Processor      7
# 3.35 GHz Processor      7
# 3.05 GHz Processor      6
# 3.78 GHz Processor      5
# 2.7 GHz Processor       5
# 2.73 GHz Processor      4
# 2.96 GHz Processor      4
# 1.82 GHz Processor      3
# 3.39 GHz Processor      3
# 3.63 GHz Processor      3
# 2.65 GHz Processor      3
# 1.3 MHz Processor       2
# 2.91 GHz Processor      2
# 2.36 GHz Processor      2
# ...

# %%
ababu['processor_speed']=ababu['processor_speed'].str.strip()

# %%
ababu['processor_speed'].value_counts()
# Out:
# 2.4 GHz Processor     158
# 2.2 GHz Processor     157
# 2 GHz Processor        76
# 3 GHz Processor        47
# 3.2 GHz Processor      44
# 2.6 GHz Processor      38
# 2.5 GHz Processor      37
# 2.3 GHz Processor      36
# 2.8 GHz Processor      28
# 1.8 GHz Processor      24
# 3.1 GHz Processor      22
# 1.6 GHz Processor      19
# 2.63 GHz Processor     17
# 2.84 GHz Processor     16
# 2.05 GHz Processor     13
# 3.3 GHz Processor      13
# 2.9 GHz Processor      10
# 3.22 GHz Processor      9
# 3.36 GHz Processor      8
# 2.85 GHz Processor      8
# 4.05 GHz Processor      7
# 3.46 GHz Processor      7
# 3.35 GHz Processor      7
# 3.05 GHz Processor      6
# 3.78 GHz Processor      5
# 2.7 GHz Processor       5
# 2.96 GHz Processor      4
# 2.73 GHz Processor      4
# 3.63 GHz Processor      3
# 2.65 GHz Processor      3
# 3.39 GHz Processor      3
# 1.82 GHz Processor      3
# 4.04 GHz Processor      2
# 3.11 GHz Processor      2
# 4.32 GHz Processor      2
# ...

# %%
ababu.to_csv("D:/smartbabu47.csv",index=False)

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                      Sim_specification  has_5g  has_nfc  \
# 0                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster    True     True
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
ababu['processor_speed']=ababu['processor_speed'].str.replace('Processor','')

# %%
ababu['processor_speed']=ababu['processor_speed'].str.strip()

# %%
ababu['processor_speed'].str.get(0)
# Out:
# 0        2
# 1        2
# 2        4
# 3        2
# 4        2
# 5        2
# 6        2
# 7        3
# 8        2
# 9        2
# 10       3
# 11       2
# 12       2
# 13       2
# 14       2
# 15       2
# 16       2
# 17       2
# 18       2
# 19       2
# 20       2
# 21       2
# 22       2
# 23       3
# 24       2
# 25       2
# 26       2
# 27       2
# 28       2
# 29       2
# 30       3
# 31       2
# 32       3
# 33       2
# 34       2
# 35       2
# 36       2
# 37       2
# 38       2
# 39       2
# 40       2
# 41       2
# 42       2
# 43       2
# 44       3
# 45       2
# 46       2
# 47       2
# 48       3
# 49       2
# 50       3
# 51       2
# 52       2
# 53       4
# 54       3
# 55       2
# 56       3
# 57       3
# 58       2
# 59       2
# 60       2
# 61       2
# 62       2
# 63       2
# 64       2
# 65       3
# 66       2
# 67       3
# 68       2
# 69       2
# 70       4
# 71       3
# 72       2
# 73       2
# 74       2
# 75       2
# ...

# %%
ababu.rename(columns={'processor_speed':'processor_speed(GHz)'},inplace=True)

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'battery_specification',
#        'display_specification', 'camera_specification',
#        'memorycard_FM_bluetooth_info', 'android_version'],
#       dtype='object')

# %%
ababu['processor_speed(GHz)']=ababu['processor_speed(GHz)'].str.get(0)

# %%
ababu[ababu['processor_speed(GHz)'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, phone_name, cost, spec_score, Sim_specification, has_5g, has_nfc, has_irblaster, Processor_specification, processor_name, num_cores, processor_speed(GHz), memory_specification, battery_specification, display_specification, camera_specification, memorycard_FM_bluetooth_info, android_version]
# Index: []

# %%
ababu.loc[ababu['index']==865,'processor_speed(GHz)']='.208'

# %%
ababu[ababu['index']==151]
# Out:
#      index      phone_name  cost  spec_score  \
# 149    151  Tecno POP 9 4G  6699          56
#
#                               Sim_specification  has_5g  has_nfc  \
# 149  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster   False    False
#
#      has_irblaster         Processor_specification processor_name  num_cores  \
# 149           True  Helio G50, Octa Core Processor      Helio G50  Octa Core
#
#     processor_speed(GHz)     memory_specification  \
# 149                  NaN  3 GB RAM, 64 GB inbuilt
#
#                    battery_specification  \
# 149  5000 mAh Battery with Fast Charging
#
#                                          display_specification  \
# 149  6.67 inches, 720 x 1600 px, 90 Hz Display with Punch Hole
#
#                camera_specification      memorycard_FM_bluetooth_info  \
# 149  13 MP Rear & Main Front Camera  Memory Card Supported, upto 1 TB
#
#     android_version
# 149     Android v14

# %%
ababu.loc[ababu['index']==211,'processor_speed(GHz)']='1.05'

# %%
ababu.to_csv("D:/smartbabu27.csv",index=False)

# %%
ababu['processor_speed(GHz)']=ababu['processor_speed(GHz)'].astype('float')

# %%
ababu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         881 non-null    int64
#  1   phone_name                    881 non-null    object
#  2   cost                          881 non-null    int64
#  3   spec_score                    881 non-null    int64
#  4   Sim_specification             881 non-null    object
#  5   has_5g                        881 non-null    bool
#  6   has_nfc                       881 non-null    bool
#  7   has_irblaster                 881 non-null    bool
#  8   Processor_specification       881 non-null    object
#  9   processor_name                873 non-null    object
#  10  num_cores                     873 non-null    object
#  11  processor_speed(GHz)          881 non-null    float64
# ...

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                      Sim_specification  has_5g  has_nfc  \
# 0                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster    True     True
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
ram_capacity=ababu['memory_specification'].str.split(',').str.get(0).str.split().str.get(0)

# %%
ram_capacity.head()
# Out:
# 0     8
# 1     4
# 2    12
# 3     8
# 4     8
# Name: memory_specification, dtype: object

# %%
calc=ababu['memory_specification'].str.split(',').str.get(0)

# %%
import numpy as np
def knh(val):
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        jh1=re.search(pattern,val)
        if jh1:
            l=jh1.group()
            return int(l)/1000
    else:
        pattern=r"\b(\d+)\b"
        jh1=re.search(pattern,val)
        if jh1:
            l=jh1.group()
            return int(l)
    return np.nan

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8 GB RAM      359
# 4 GB RAM      171
# 6 GB RAM      152
# 12 GB RAM     138
# 16 GB RAM      20
# 3 GB RAM       19
# 2 GB RAM        8
# 64 MB RAM       3
# 18 GB RAM       2
# 8 MB RAM        2
# 32 MB RAM       2
# 512 MB RAM      1
# 48 MB RAM       1
# Name: ram_capacity(GB), dtype: int64

# %%
ababu['ram_capacity(GB)'].apply(knh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\4082790069.py in <module>
# ----> 1 ababu['ram_capacity(GB)'].apply(knh)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# ...

# %%
ram_capacity=ababu['memory_specification'].str.split(',').str.get(0)

# %%
internal_capacity=ababu['memory_specification'].str.split(',').str.get(1)
internal_ca

# %%
ababu.insert(13,'ram_capacity(GB)',ram_capacity)

# %%
ababu.insert(14,'internal_capacity(GB)',internal_capacity)

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'ram_capacity(GB)', 'internal_capacity(GB)',
#        'battery_specification', 'display_specification',
#        'camera_specification', 'memorycard_FM_bluetooth_info',
#        'android_version'],
#       dtype='object')

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8 GB RAM      359
# 4 GB RAM      171
# 6 GB RAM      152
# 12 GB RAM     138
# 16 GB RAM      20
# 3 GB RAM       19
# 2 GB RAM        8
# 64 MB RAM       3
# 18 GB RAM       2
# 8 MB RAM        2
# 32 MB RAM       2
# 512 MB RAM      1
# 48 MB RAM       1
# Name: ram_capacity(GB), dtype: int64

# %%
ababu.to_csv("D:/humbasmarthumba.csv",index=False)

# %%
import pandas as pd 
ababu=pd.read_csv("D:/humbasmarthumba.csv")
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                    Sim_specification  has_5g  has_nfc  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
temp2=ababu[ababu['ram_capacity(GB)'].isin(['128 GB inbuilt','256 GB inbuilt','512 GB inbuilt'])][['ram_capacity(GB)','internal_capacity(GB)']].shift(1,axis=1)
temp2
# Out:
#     ram_capacity(GB) internal_capacity(GB)
# 190              NaN        128 GB inbuilt
# 466              NaN        256 GB inbuilt
# 693              NaN        512 GB inbuilt

# %%
ababu.loc[temp2.index,['ram_capacity(GB)','internal_capacity(GB)']]=temp2.values

# %%
ababu.drop(columns=['ram_capacity(GB)'],inplace=True)

# %%
gh='8 MB RAM'
if 'MB' in gh:
    print("ok")
else:
    print('gk')
# Out:
# ok

# %%
import re
pattern =r"\b(\d+)\b"
ak=re.search(pattern,gh)
print(int(ak.group())/4)
# Out:
# 2.0

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'ram_capacity': [
        '8 GB RAM', '4 GB RAM', '6 GB RAM', '12 GB RAM',
        '16 GB RAM', '3 GB RAM', '2 GB RAM', np.nan,
        '64 MB RAM', '18 GB RAM', '8 MB RAM', '32 MB RAM',
        '512 MB RAM', '48 MB RAM', np.nan
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32780\3584214314.py in <module>
#       5     'ram_capacity': [
#       6         '8 GB RAM', '4 GB RAM', '6 GB RAM', '12 GB RAM',
# ----> 7         '16 GB RAM', '3 GB RAM', '2 GB RAM', np.nan,
#       8         '64 MB RAM', '18 GB RAM', '8 MB RAM', '32 MB RAM',
#       9         '512 MB RAM', '48 MB RAM', np.nan
#
# NameError: name 'np' is not defined

# %%
def kvh(val):
    if 'MB' in val:
        a=str(val)
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,a)
        if ak:
            return ak.group()
    else:
        a=str(val)
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,a)
        if ak:
            return ak.group()
df['ram_capacity'].apply(kvh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\500273333.py in <module>
#      12         if ak:
#      13             return ak.group()
# ---> 14 df['ram_capacity'].apply(kvh)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
import pandas as pd
import numpy as np
# Data for the DataFrame
data = {
    'ram_capacity': [
        '8 GB RAM', '4 GB RAM', '6 GB RAM', '12 GB RAM',
        '16 GB RAM', '3 GB RAM', '2 GB RAM', np.nan,
        '64 MB RAM', '18 GB RAM', '8 MB RAM', '32 MB RAM',
        '512 MB RAM', '48 MB RAM', np.nan,'Mahendra singh'
    ]
}

# Create the DataFrame
df1 = pd.DataFrame(data)

# Display the DataFrame
print(df1)
# Out:
#       ram_capacity
# 0         8 GB RAM
# 1         4 GB RAM
# 2         6 GB RAM
# 3        12 GB RAM
# 4        16 GB RAM
# 5         3 GB RAM
# 6         2 GB RAM
# 7              NaN
# 8        64 MB RAM
# 9        18 GB RAM
# 10        8 MB RAM
# 11       32 MB RAM
# 12      512 MB RAM
# 13       48 MB RAM
# 14             NaN
# 15  Mahendra singh

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'ram_capacity': [
        '8 GB RAM', '4 GB RAM', '6 GB RAM', '12 GB RAM',
        '16 GB RAM', '3 GB RAM', '2 GB RAM',
        '64 MB RAM', '18 GB RAM', '8 MB RAM', '32 MB RAM',
        '512 MB RAM', '48 MB RAM'
    ]
}

# Create the DataFrame
df2 = pd.DataFrame(data)

# Display the DataFrame
print(df2)
# Out:
#    ram_capacity
# 0      8 GB RAM
# 1      4 GB RAM
# 2      6 GB RAM
# 3     12 GB RAM
# 4     16 GB RAM
# 5      3 GB RAM
# 6      2 GB RAM
# 7     64 MB RAM
# 8     18 GB RAM
# 9      8 MB RAM
# 10    32 MB RAM
# 11   512 MB RAM
# 12    48 MB RAM

# %%
import re
def kvh(val):
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return ak.group()
    else:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return ak.group()
df2['ram_capacity'].apply(kvh)
# Out:
# 0       8
# 1       4
# 2       6
# 3      12
# 4      16
# 5       3
# 6       2
# 7      64
# 8      18
# 9       8
# 10     32
# 11    512
# 12     48
# Name: ram_capacity, dtype: object

# %%
import re
def kvh(val):
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            fd=ak.group()
            return int(fd)/1000
    else:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return int(ak.group())
df2['ram_capacity'].apply(kvh)
# Out:
# 0      8.000
# 1      4.000
# 2      6.000
# 3     12.000
# 4     16.000
# 5      3.000
# 6      2.000
# 7      0.064
# 8     18.000
# 9      0.008
# 10     0.032
# 11     0.512
# 12     0.048
# Name: ram_capacity, dtype: float64

# %%
df2
# Out:
#    ram_capacity
# 0      8 GB RAM
# 1      4 GB RAM
# 2      6 GB RAM
# 3     12 GB RAM
# 4     16 GB RAM
# 5      3 GB RAM
# 6      2 GB RAM
# 7     64 MB RAM
# 8     18 GB RAM
# 9      8 MB RAM
# 10    32 MB RAM
# 11   512 MB RAM
# 12    48 MB RAM

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'ram_capacity': [
        '8 GB RAM', '4 GB RAM', '6 GB RAM', '12 GB RAM',
        '16 GB RAM', '3 GB RAM', '2 GB RAM',
        '64 MB RAM', '18 GB RAM', '8 MB RAM', '32 MB RAM',
        '512 MB RAM', '48 MB RAM','Mahendra singh'
    ]
}

# Create the DataFrame
df3 = pd.DataFrame(data)

# Display the DataFrame
print(df3)
# Out:
#       ram_capacity
# 0         8 GB RAM
# 1         4 GB RAM
# 2         6 GB RAM
# 3        12 GB RAM
# 4        16 GB RAM
# 5         3 GB RAM
# 6         2 GB RAM
# 7        64 MB RAM
# 8        18 GB RAM
# 9         8 MB RAM
# 10       32 MB RAM
# 11      512 MB RAM
# 12       48 MB RAM
# 13  Mahendra singh

# %%
import re
def kvh(val):
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            fd=ak.group()
            return int(fd)/1000
    else:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return int(ak.group())
df3['ram_capacity'].apply(kvh)
# Out:
# 0      8.000
# 1      4.000
# 2      6.000
# 3     12.000
# 4     16.000
# 5      3.000
# 6      2.000
# 7      0.064
# 8     18.000
# 9      0.008
# 10     0.032
# 11     0.512
# 12     0.048
# 13       NaN
# Name: ram_capacity, dtype: float64

# %%
df1
# Out:
#       ram_capacity
# 0         8 GB RAM
# 1         4 GB RAM
# 2         6 GB RAM
# 3        12 GB RAM
# 4        16 GB RAM
# 5         3 GB RAM
# 6         2 GB RAM
# 7              NaN
# 8        64 MB RAM
# 9        18 GB RAM
# 10        8 MB RAM
# 11       32 MB RAM
# 12      512 MB RAM
# 13       48 MB RAM
# 14             NaN
# 15  Mahendra singh

# %%
import re
import pandas as pd
def kvh(val):
    if pd.isnull(val):
        return np.nan
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            fd=ak.group()
            return int(fd)/1000
    else:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return int(ak.group())
df1['ram_capacity'].apply(kvh)
# Out:
# 0      8.000
# 1      4.000
# 2      6.000
# 3     12.000
# 4     16.000
# 5      3.000
# 6      2.000
# 7        NaN
# 8      0.064
# 9     18.000
# 10     0.008
# 11     0.032
# 12     0.512
# 13     0.048
# 14       NaN
# 15       NaN
# Name: ram_capacity, dtype: float64

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8 GB RAM      359
# 4 GB RAM      171
# 6 GB RAM      152
# 12 GB RAM     138
# 16 GB RAM      20
# 3 GB RAM       19
# 2 GB RAM        8
# 64 MB RAM       3
# 18 GB RAM       2
# 8 MB RAM        2
# 32 MB RAM       2
# 512 MB RAM      1
# 48 MB RAM       1
# Name: ram_capacity(GB), dtype: int64

# %%
ababu['internal_capacity(GB)'].value_counts()
# Out:
# 128 GB inbuilt    1
# 256 GB inbuilt    1
# 512 GB inbuilt    1
# Name: internal_capacity(GB), dtype: int64

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                    Sim_specification  has_5g  has_nfc  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
ababu.drop(columns=['ram_capacity(GB)','internal_capacity(GB)'],inplace=True)

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                    Sim_specification  has_5g  has_nfc  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
ram_capacity_GB=ababu['memory_specification'].str.split(',').str.get(0)

# %%
internal_capacity_GB=ababu['memory_specification'].str.split(',').str.get(1)

# %%
ababu.insert(13,'ram_capacity(GB)',ram_capacity_GB)

# %%
ababu.insert(14,'internal_capacity(GB)',internal_capacity_GB)

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8 GB RAM          359
# 4 GB RAM          171
# 6 GB RAM          152
# 12 GB RAM         138
# 16 GB RAM          20
# 3 GB RAM           19
# 2 GB RAM            8
# 64 MB RAM           3
# 18 GB RAM           2
# 8 MB RAM            2
# 32 MB RAM           2
# 128 GB inbuilt      1
# 512 MB RAM          1
# 256 GB inbuilt      1
# 512 GB inbuilt      1
# 48 MB RAM           1
# Name: ram_capacity(GB), dtype: int64

# %%
temp1=ababu[ababu['ram_capacity(GB)'].isin(['128 GB inbuilt','256 GB inbuilt','512 GB inbuilt'])][['ram_capacity(GB)','internal_capacity(GB)']]

# %%
temp1=temp1.shift(1,axis=1)

# %%
temp1
# Out:
#     ram_capacity(GB) internal_capacity(GB)
# 190              NaN        128 GB inbuilt
# 466              NaN        256 GB inbuilt
# 693              NaN        512 GB inbuilt

# %%
ababu.loc[temp1.index,['ram_capacity(GB)','internal_capacity(GB)']]=temp1.values

# %%
ababu.loc[temp1.index,['ram_capacity(GB)','internal_capacity(GB)']]
# Out:
#     ram_capacity(GB) internal_capacity(GB)
# 190              NaN        128 GB inbuilt
# 466              NaN        256 GB inbuilt
# 693              NaN        512 GB inbuilt

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8 GB RAM      359
# 4 GB RAM      171
# 6 GB RAM      152
# 12 GB RAM     138
# 16 GB RAM      20
# 3 GB RAM       19
# 2 GB RAM        8
# 64 MB RAM       3
# 18 GB RAM       2
# 8 MB RAM        2
# 32 MB RAM       2
# 512 MB RAM      1
# 48 MB RAM       1
# Name: ram_capacity(GB), dtype: int64

# %%
ababu['internal_capacity(GB)'].value_counts()
# Out:
#  128 GB inbuilt    407
#  256 GB inbuilt    254
#  64 GB inbuilt     121
#  512 GB inbuilt     59
#  32 GB inbuilt      17
#  1 TB inbuilt        9
#  128 MB inbuilt      3
#  16 GB inbuilt       2
#  16 MB inbuilt       2
#  32 MB inbuilt       2
# 128 GB inbuilt       1
#  4 GB inbuilt        1
# 256 GB inbuilt       1
# 512 GB inbuilt       1
#  48 MB inbuilt       1
# Name: internal_capacity(GB), dtype: int64

# %%
import re
import pandas as pd
def kvh(val):
    if pd.isnull(val):
        return np.nan
    if 'MB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            fd=ak.group()
            return int(fd)/1000
    elif 'TB' in val:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            fd=ak.group()
            return int(fd)*1000
        
    else:
        pattern=r"\b(\d+)\b"
        ak=re.search(pattern,val)
        if ak:
            return int(ak.group())

# %%
ababu['ram_capacity(GB)']=ababu['ram_capacity(GB)'].apply(kvh)

# %%
ababu['ram_capacity(GB)'].value_counts()
# Out:
# 8.000     359
# 4.000     171
# 6.000     152
# 12.000    138
# 16.000     20
# 3.000      19
# 2.000       8
# 0.064       3
# 18.000      2
# 0.008       2
# 0.032       2
# 0.512       1
# 0.048       1
# Name: ram_capacity(GB), dtype: int64

# %%
ababu['internal_capacity(GB)']=ababu['internal_capacity(GB)'].apply(kvh)

# %%
ababu['internal_capacity(GB)'].value_counts()
# Out:
# 128.000     408
# 256.000     255
# 64.000      121
# 512.000      60
# 32.000       17
# 1000.000      9
# 0.128         3
# 16.000        2
# 0.016         2
# 0.032         2
# 4.000         1
# 0.048         1
# Name: internal_capacity(GB), dtype: int64

# %%
ababu.to_csv("D:/wahbabumahendrasmartie.csv",index=False)

# %%
ababu[ababu['ram_capacity(GB)'].isna()]
# Out:
#      index                    phone_name    cost  spec_score  \
# 466    485  Apple iPhone 16 Plus (256GB)   97900          75
# 693    738  Apple iPhone 16 Plus (512GB)  119900          76
#
#                            Sim_specification  has_5g  has_nfc  has_irblaster  \
# 466  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True          False
# 693  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True          False
#
#             Processor_specification processor_name  num_cores  \
# 466  Apple A18, Hexa Core Processor      Apple A18  Hexa Core
# 693  Apple A18, Hexa Core Processor      Apple A18  Hexa Core
#
#      processor_speed(GHz) memory_specification  ram_capacity(GB)  \
# 466                  4.04       256 GB inbuilt               NaN
# 693                  4.04       512 GB inbuilt               NaN
#
#      internal_capacity(GB)                battery_specification  \
# 466                  256.0  4674 mAh Battery with Fast Charging
# ...

# %%
ababu.loc[ababu['index']==193,'ram_capacity(GB)']=8.0

# %%
pd.set_option('display.max_rows', None)

# %%
ababu['battery_specification'].value_counts()
# Out:
# 5000 mAh Battery with 33W Fast Charging      85
# 5000 mAh Battery with 18W Fast Charging      85
# 5000 mAh Battery with 45W Fast Charging      55
# 5000 mAh Battery with 15W Fast Charging      39
# 5000 mAh Battery with 25W Fast Charging      38
# 5000 mAh Battery with 67W Fast Charging      37
# 5000 mAh Battery with 10W Fast Charging      36
# 5000 mAh Battery with 80W Fast Charging      22
# 6000 mAh Battery with 25W Fast Charging      20
# 5500 mAh Battery with 80W Fast Charging      17
# 5000 mAh Battery                             14
# 5000 mAh Battery with 44W Fast Charging      13
# 4500 mAh Battery with 65W Fast Charging      12
# 5000 mAh Battery with 120W Fast Charging     12
# 5000 mAh Battery with 68W Fast Charging      10
# 6000 mAh Battery with 18W Fast Charging       9
# 5100 mAh Battery with 45W Fast Charging       9
# 5500 mAh Battery with 100W Fast Charging      8
# 4500 mAh Battery with 25W Fast Charging       8
# 6000 mAh Battery with 44W Fast Charging       7
# ...

# %%
ababu['battery_specification']
# Out:
# 0        5000 mAh Battery with 80W Fast Charging
# 1        5160 mAh Battery with 18W Fast Charging
# 2       5800 mAh Battery with 120W Fast Charging
# 3        5100 mAh Battery with 67W Fast Charging
# 4        5000 mAh Battery with 67W Fast Charging
# 5        5500 mAh Battery with 80W Fast Charging
# 6        5000 mAh Battery with 68W Fast Charging
# 7        5000 mAh Battery with 45W Fast Charging
# 8        5000 mAh Battery with 80W Fast Charging
# 9       5000 mAh Battery with 120W Fast Charging
# 10       5910 mAh Battery with 80W Fast Charging
# 11       5000 mAh Battery with 33W Fast Charging
# 12       5000 mAh Battery with 25W Fast Charging
# 13       4500 mAh Battery with 68W Fast Charging
# 14       5500 mAh Battery with 44W Fast Charging
# 15       5160 mAh Battery with 18W Fast Charging
# 16       6000 mAh Battery with 25W Fast Charging
# 17       6000 mAh Battery with 44W Fast Charging
# 18       5000 mAh Battery with 33W Fast Charging
# ...

# %%
battery_capacity=ababu['battery_specification'].str.split('with').str.get(0).str.findall(r"\b(\d+)\b").str.get(0)

# %%
fast_charging=ababu['battery_specification'].str.split('with').str.get(1).str.findall(r"(\d+)").str.get(0)

# %%
ababu.insert(16,'battery_capacity(mAh)',battery_capacity)

# %%
ababu.insert(17,'fast_charging(W)',fast_charging)

# %%
ababu[ababu['fast_charging(W)'].isna()]
# Out:
#      index                                phone_name    cost  spec_score  \
# 48      50                           Apple iPhone 15   58249          83
# 53      55                   Apple iPhone 16 Pro Max  144900          90
# 70      72                           Apple iPhone 16   76900          87
# 87      89                           Apple iPhone 13   45490          78
# 98     100                      Apple iPhone 15 Plus   65499          84
# 110    112                       Apple iPhone 16 Pro  119900          89
# 121    123                           Google Pixel 8A   39999          78
# 126    128                   Apple iPhone 15 Pro Max  119900          89
# 149    151                            Tecno POP 9 4G    6699          56
# 153    155                           Apple iPhone 14   52990          80
# 190    193                      Apple iPhone 16 Plus   86900          85
# 225    228                      Apple iPhone 14 Plus   56999          82
# ...

# %%
ababu.loc[ababu['index']==914,'battery_capacity(mAh)']='2815'

# %%
ababu.loc[ababu['index']==914,'fast_charging(W)']='20'

# %%
ababu['battery_capacity(mAh)']=ababu['battery_capacity(mAh)'].astype('int')

# %%
ababu['fast_charging(W)']=ababu['fast_charging(W)'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32780\488577553.py in <module>
# ----> 1 ababu['fast_charging(W)']=ababu['fast_charging(W)'].astype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'ram_capacity(GB)', 'internal_capacity(GB)',
#        'battery_specification', 'battery_capacity(mAh)', 'fast_charging(W)',
#        'display_specification', 'camera_specification',
#        'memorycard_FM_bluetooth_info', 'android_version'],
#       dtype='object')

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                    Sim_specification  has_5g  has_nfc  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_colwidth', None)

# %%
screen_size=ababu['display_specification'].str.split(',').str.get(0).str.findall(r"([\d\.]+)").str.get(0).astype('float')

# %%
ababu.insert(19,'screen_size(inches)',screen_size)

# %%
resolution=ababu['display_specification'].str.split(',').str.get(1).str.split('px').str.get(0).str.strip()

# %%
ababu.insert(20,'resolution(px)',resolution)

# %%
#for isna make 60 
refresh_rate=ababu['display_specification'].str.split(',').str.get(2).str.split('Hz').str.get(0).str.strip().apply(lambda x:'60' if pd.isna(x) else x).astype('int')

# %%
ababu.insert(21,'refresh_rate(Hz)',refresh_rate)

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'ram_capacity(GB)', 'internal_capacity(GB)',
#        'battery_specification', 'battery_capacity(mAh)', 'fast_charging(W)',
#        'display_specification', 'screen_size(inches)', 'resolution(px)',
#        'refresh_rate(Hz)', 'camera_specification',
#        'memorycard_FM_bluetooth_info', 'android_version'],
#       dtype='object')

# %%
def num_extract(val):
    if 'Dual' in val:
        return '2'
    elif 'Triple' in val:
        return '3'
    elif 'Quad' in val:
        return 4

# %%
rear_camera=ababu['camera_specification'].str.split('&').str.get(0).apply(ext)

# %%
ababu.insert(23,'rear_camera(MP)',rear_camera)

# %%
ababu[ababu['rear_camera(MP)'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, phone_name, cost, spec_score, Sim_specification, has_5g, has_nfc, has_irblaster, Processor_specification, processor_name, num_cores, processor_speed(GHz), memory_specification, ram_capacity(GB), internal_capacity(GB), battery_specification, battery_capacity(mAh), fast_charging(W), display_specification, screen_size(inches), resolution(px), refresh_rate(Hz), camera_specification, rear_camera(MP), memorycard_FM_bluetooth_info, android_version]
# Index: []

# %%
def ext(val):
    if 'MP Front Camera' in val:
        return '1'
    elif 'Main Front Camera' in val:
        return '1'
    elif 'Dual' in val:
        return '2'
    elif 'Missing' in val:
        return 'Missing'

# %%
front_camera=ababu['camera_specification'].str.split('&').str.get(1).str.strip().fillna('Missing').apply(ext)

# %%
ababu.insert(24,'front_camera(MP)',front_camera)

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'ram_capacity(GB)', 'internal_capacity(GB)',
#        'battery_specification', 'battery_capacity(mAh)', 'fast_charging(W)',
#        'display_specification', 'screen_size(inches)', 'resolution(px)',
#        'refresh_rate(Hz)', 'camera_specification', 'rear_camera(MP)',
#        'front_camera(MP)', 'memorycard_FM_bluetooth_info', 'android_version'],
#       dtype='object')

# %%
ababu['camera_specification'].head()
# Out:
# 0              50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 1                      50 MP Dual Rear & 5 MP Front Camera
# 2    50 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera
# 3    200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 4    108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera
# Name: camera_specification, dtype: object

# %%
ababu['memorycard_FM_bluetooth_info'].value_counts()
# Out:
# No FM Radio                                           169
# Memory Card Not Supported                             166
# Memory Card Supported, upto 1 TB                      152
# Memory Card (Hybrid), upto 1 TB                       142
# Not Specified                                          56
# Memory Card Supported, upto 512 GB                     43
# Memory Card (Hybrid), upto 2 TB                        42
# Memory Card Supported, upto 2 TB                       36
# Memory Card Supported, upto 256 GB                     23
# Bluetooth                                              22
# Memory Card (Hybrid), upto 256 GB                       7
# Memory Card (Hybrid), upto 512 GB                       7
# Memory Card (Hybrid), upto 1.5 TB                       3
# Memory Card Supported, upto 64 GB                       3
# Memory Card Supported, upto 32 GB                       3
# Memory Card (Hybrid), upto 128 GB                       2
# ...

# %%
ajm=ababu['memorycard_FM_bluetooth_info'].apply(lambda x:0 if 'Not' in x else x.split('upto')).str.get(-1).str.strip()
ajm
# Out:
# 0             2 TB
# 1             1 TB
# 2              NaN
# 3      No FM Radio
# 4             1 TB
# 5              NaN
# 6              NaN
# 7              NaN
# 8      No FM Radio
# 9              NaN
# 10     No FM Radio
# 11             NaN
# 12          1.5 TB
# 13     No FM Radio
# 14       Bluetooth
# 15            1 TB
# 16            1 TB
# 17            1 TB
# 18            1 TB
# 19             NaN
# 20             NaN
# 21            1 TB
# 22            1 TB
# 23     No FM Radio
# 24            1 TB
# 25            2 TB
# 26     No FM Radio
# 27            2 TB
# 28     No FM Radio
# 29            2 TB
# 30     No FM Radio
# 31            1 TB
# 32             NaN
# 33            2 TB
# 34            2 TB
# 35     No FM Radio
# 36             NaN
# 37            1 TB
# 38            1 TB
# 39            1 TB
# 40            1 TB
# 41            1 TB
# 42             NaN
# 43            2 TB
# 44             NaN
# 45            1 TB
# 46             NaN
# ...

# %%
ababu.insert(26,'extended_memory',ajm)

# %%
ababu.columns
# Out:
# Index(['index', 'phone_name', 'cost', 'spec_score', 'Sim_specification',
#        'has_5g', 'has_nfc', 'has_irblaster', 'Processor_specification',
#        'processor_name', 'num_cores', 'processor_speed(GHz)',
#        'memory_specification', 'ram_capacity(GB)', 'internal_capacity(GB)',
#        'battery_specification', 'battery_capacity(mAh)', 'fast_charging(W)',
#        'display_specification', 'screen_size(inches)', 'resolution(px)',
#        'refresh_rate(Hz)', 'camera_specification', 'rear_camera(MP)',
#        'front_camera(MP)', 'memorycard_FM_bluetooth_info', 'extended_memory',
#        'android_version'],
#       dtype='object')

# %%
temp=ababu[ababu['memorycard_FM_bluetooth_info']=='Memory Card Supported']

# %%
ababu['android_version'].value_counts()
# Out:
# Android v14                     326
# Android v13                     217
# Android v12                     122
# Android v11                      89
# Android v10                      28
# iOS v18                          13
# Android v9.0 (Pie)               13
# iOS v17                          11
# Android v10.0                     7
# iOS v16                           6
# Android v15                       5
# iOS v15                           4
# iOS v13                           3
# Android v8.1 (Oreo)               2
# iOS v14.0                         2
# iOS v14                           2
# RTOS (Series 30+)                 2
# S30+                              1
# iOS v11                           1
# Android v6.0.1 (Marshmallow)      1
# Symbian                           1
# Symbian v0.1                      1
# Name: android_version, dtype: int64

# %%
ababu['memorycard_FM_bluetooth_info'].head()
# Out:
# 0     Memory Card (Hybrid), upto 2 TB
# 1    Memory Card Supported, upto 1 TB
# 2           Memory Card Not Supported
# 3                         No FM Radio
# 4     Memory Card (Hybrid), upto 1 TB
# Name: memorycard_FM_bluetooth_info, dtype: object

# %%
ababu.loc[temp.index,'memorycard_FM_bluetooth_info']='Not Specified'

# %%
ababu.head()
# Out:
#    index                   phone_name   cost  spec_score  \
# 0      2                 Vivo Y300 5G  21999          83
# 1      3           Xiaomi Redmi A4 5G   8499          70
# 2      4           Realme GT 7 Pro 5G  59999          90
# 3      5  Xiaomi Redmi Note 13 Pro 5G  17724          83
# 4      6    OnePlus Nord CE 3 Lite 5G  14705          85
#
#                                      Sim_specification  has_5g  has_nfc  \
# 0                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster    True     True
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 4                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#    has_irblaster                            Processor_specification  \
# 0          False    Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# ...

# %%
export_df = ababu.drop(columns=['index','Sim_specification','Processor_specification','memory_specification','battery_specification','display_specification','camera_specification','memorycard_FM_bluetooth_info'])

# %%
export_df.to_csv("D:/rana1.csv",index=False)

# %%
ababu['display_specification'].head()
# Out:
# 0         6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 1    6.88 inches, 720 x 1640 px, 120 Hz Display with Water Drop Notch
# 2         6.78 inches, 1264 x 2780 px, 120 Hz Display with Punch Hole
# 3         6.67 inches, 1220 x 2712 px, 120 Hz Display with Punch Hole
# 4         6.72 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# Name: display_specification, dtype: object

# %%
ababu.to_csv("D:/rana2.csv",index=False)

# %%
rs="6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole"
import re 
pattern=r"(\d+\.\d+)"
us=re.findall(pattern,rs)
print(us)
# Out:
# ['6.67']

# %%
import pandas as pd

# List of camera specifications
camera_specs = [
    "13 MP Dual Rear",
    "108 MP Quad Rear",
    "13 MP Rear",
    "48 MP + 8 MP + 2 MP Triple Rear",
    "48 MP + 2 MP + 2 MP Triple Rear",
    "50 MP + Depth Sensor Dual Rear",
    "48 MP + 48 MP + 12 MP Triple Rear",
    "50 MP + 13 MP Dual Rear",
    "200 MP Quad Rear",
    "48 MP + 8 MP + 5 MP Triple Rear",
    "8 MP Rear",
    "8 MP Dual Rear",
    "No Rear Camera"
]

# Create a DataFrame
df = pd.DataFrame(camera_specs, columns=["Camera Specifications"])

# Display the DataFrame
print(df)
# Out:
#                 Camera Specifications
# 0                     13 MP Dual Rear
# 1                    108 MP Quad Rear
# 2                          13 MP Rear
# 3     48 MP + 8 MP + 2 MP Triple Rear
# 4     48 MP + 2 MP + 2 MP Triple Rear
# 5      50 MP + Depth Sensor Dual Rear
# 6   48 MP + 48 MP + 12 MP Triple Rear
# 7             50 MP + 13 MP Dual Rear
# 8                    200 MP Quad Rear
# 9     48 MP + 8 MP + 5 MP Triple Rear
# 10                          8 MP Rear
# 11                     8 MP Dual Rear
# 12                     No Rear Camera

# %%
def ext(val):
    if 'Dual' in val:
        return '2'
    elif 'Triple' in val:
        return '3'
    elif 'Quad' in val:
        return '4'
    elif 'MP' in val:
        return '1'
    elif 'No' in val:
        return '0'

# %%
df['Camera Specifications'].apply(ext)
# Out:
# 0     2
# 1     4
# 2     1
# 3     3
# 4     3
# 5     2
# 6     3
# 7     2
# 8     4
# 9     3
# 10    1
# 11    2
# 12    0
# Name: Camera Specifications, dtype: object
